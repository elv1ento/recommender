# %%
from recommender import HybridRecommender

# %%
recommender = HybridRecommender()
# Out:
# normalized_dask.csv: Dataset loaded.
# search_model.pkl: Model loaded.
# normalized_dask.csv: Dataset loaded.
# tfidf_matrix.pkl: Model loaded.
# Dataset loaded.
# NN_cosine.pkl: Model loaded.

# %%
user_query = 'a book about magic and adventures in Middle-earth'

# %%
# %%time
search_results = recommender.search(user_query)
# Out:
# CPU times: user 281 ms, sys: 8.83 ms, total: 290 ms
# Wall time: 287 ms

# %%
search_results
# Out:
#                                                    Book-Title  \
# ISBN
# 0152020780                                    Seven-Day Magic
# 0553252429  The Magic of the Unicorn (Create Your Own Adve...
# 0880381981  Thunder over Jotunheim (Marvel Super Heroes mo...
# 0590403605  The Magic School Bus: At the Waterworks (Magic...
# 0340427205       Asterix and the Magic Carpet (Asterix Comic)
# 0441948405                                  The Yoke of Magic
# 0590988247   Sunset of the Sabertooth (Magic Tree House, # 7)
# 0679883398  Ghost Town At Sundown (Magic Tree House 10, pa...
# 0886776244      World Without End (Moontide &amp; Magic Rise)
# 0064421740    Stanley in Space (A Stanley Lambchop Adventure)
#
#                       Book-Author Year-Of-Publication  \
# ISBN
# 0152020780           Edward Eager                1999
# 0553252429  Deborah Lerme Goodman                1985
# 0880381981          Bruce Nesmith                1985
# ...

# %%
# TODO: create interactive multiple choice fields to select books from search

# %%
target_items = search_results.sample(5).index.tolist()

# %%
# %%time
best_results = recommender.total_similarities(target_items)
# Out:
# CPU times: user 675 ms, sys: 276 ms, total: 951 ms
# Wall time: 616 ms

# %%
best_results.iloc[:, :-3]
# Out:
#                                                    Book-Title  \
# ISBN
# 0860097374                               A Fugitive from Love
# 000617843X                         The Brow of the Gallowgate
# 0842319050  A Victorian Christmas Cottage (HeartQuest Anth...
# 081447103X  Do You Dot-Com? : A Field Guide to Understandi...
# 0880380535                                   Isle of Dread X1
# 0880381981  Thunder over Jotunheim (Marvel Super Heroes mo...
# 0880381256  The Breeder Bombs (Marvel Super Heroes module ...
# 0880381310       Lone Wolves (Marvel Super Heroes module MH4)
# 0880381329         Cat's-Paw (Marvel Super Heroes module MH5)
# 1560763574  Fighter's Challenge (Advanced Dungeons &amp; D...
# 0880381280  Avengers Assembled! (Marvel Super Heroes modul...
# 0880381272         Time Trap (Marvel Super Heroes module MH2)
# 0789715341  10 Minute Guide to Lotus Notes Mail 4.6 (Ten M...
# 0679883398  Ghost Town At Sundown (Magic Tree House 10, pa...
# ...

# %%
user_query = 'I want to read a book about a hobby related to handicrafts'

# %%
# %%time
search_results = recommender.search(user_query)
# Out:
# CPU times: user 391 ms, sys: 10.1 ms, total: 402 ms
# Wall time: 400 ms

# %%
search_results
# Out:
#                                                    Book-Title  \
# ISBN
# 0965112608  Awakening Brilliance: How to Inspire Children ...
# 0688116639  Victoria: A Woman's Christmas: Returning to th...
# 1850292469                Tricia Guild's new soft furnishings
# 1591131510                       Hunting for Mr. Good Bargain
# 0967983320            Dimensional Flowers, Leaves &amp; Vines
# 0595206425                                My Brother's Keeper
# 0553483765  Before They Rode Horses (Saddle Club Super Edi...
# 0966429702                               200 Beats Per Minute
# 0911214607  The human side of human beings: The theory of ...
# 0486235793                 World War I Uniforms Coloring Book
#
#                         Book-Author Year-Of-Publication  \
# ISBN
# 0965112608              Pamela Sims                1996
# 0688116639  Arlene Hamilton Stewart                1995
# 1850292469             Tricia Guild                1990
# ...

# %%
target_items = search_results.sample(5).index.tolist()

# %%
# %%time
best_results = recommender.total_similarities(target_items)
# Out:
# CPU times: user 663 ms, sys: 216 ms, total: 879 ms
# Wall time: 401 ms

# %%
best_results.iloc[:, :-3]
# Out:
#                                                    Book-Title  \
# ISBN
# 0698116879                   Everyone Else's Parents Said Yes
# 0964607719                               Sea Anemone Beadwork
# 0967983320            Dimensional Flowers, Leaves &amp; Vines
# 096459577X  The Chain &amp; Crystal Book: Techniques for B...
# 0449902757           Gem Magic: The Wonder of Your Birthstone
# 0446312428                                  Murder in Waiting
# 0725101334  Bazza pulls it off!: More adventures of Barry ...
# 0516260308           Dan Marino (Grolier All-Pro Biographies)
# 0969332238                           Cakes (Company's Coming)
# 0965112608  Awakening Brilliance: How to Inspire Children ...
# 0451407911                                        Desert Fury
# 0451170601               Arabian Nightmare (Destroyer, No 86)
# 0701118822  Bring Me a Unicorn: Diaries and Letters of Ann...
# 047152543X  The Play Therapy Primer: An Integration of The...
# ...
